# %% [markdown]
# # Automatización de Flujos E2E con Playwright
#
# Este notebook demuestra la automatización de flujos end-to-end:
#
# - Login válido
# - Login inválido
# - Creación de tareas
# - Filtrado
# - Logout
#
# Se utiliza Playwright con Python.

# %%
from playwright.sync_api import sync_playwright

# %% [markdown]
# ## 1. Login válido
